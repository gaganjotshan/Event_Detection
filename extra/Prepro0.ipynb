# %% [markdown]
# # New section

# %%
import nltk

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import pandas as pd

# %% [markdown]
# Read the individual lines from the text file

# %%
file = open('/content/drive/MyDrive/SemEval2010_task8_all_data/SemEval2010_task8_training/TRAIN_FILE.TXT','r')

# %%
lines = file.readlines()
count = 0
# Strips the newline character
for line in lines:
    count += 1
    #print("Line{}: {}".format(count, line.strip()))

# %% [markdown]
# save the lines in dataframe and convert the .txt file into csv file

# %%
df = pd.DataFrame(lines)

# %%
df.to_csv(r'/content/drive/MyDrive/SemEval2010_task8_all_data/SemEval2010_task8_training/TRAIN_FILE_0.csv', index=None)

# %%
paragraph = pd.read_csv('/content/drive/MyDrive/SemEval2010_task8_all_data/SemEval2010_task8_training/TRAIN_FILE_0.csv', header=None)
paragraph.head()
# Out:
#                                                    0
# 0                                                  0
# 1  1\t"The system as described above has its grea...
# 2                           Component-Whole(e2,e1)\n
# 3  Comment: Not a collection: there is structure ...
# 4                                                 \n

# %%
df.head()
# Out:
#                                                    0
# 0  1\t"The system as described above has its grea...
# 1                           Component-Whole(e2,e1)\n
# 2  Comment: Not a collection: there is structure ...
# 3                                                 \n
# 4  2\t"The <e1>child</e1> was carefully wrapped a...
